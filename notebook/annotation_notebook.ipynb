# %%
import os
import sys
sys.path.append(os.path.join(BASE_DIR, "constants")

# %%
from pymongo import MongoClient
import spacy
import en_core_web_lg
from spacy import displacy


from constants.category import category_map

# %%
BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath('__file__')))
job_model_path = os.path.join(BASE_DIR, "job_model_sm")

# %%
class MongoManager:
    def __init__(self):
#         user = 'root'
#         password = 'root'
#         self.client = MongoClient(f'mongodb://{user}:{password}@192.168.1.39', 27018)
        self.client = MongoClient(f'mongodb://127.0.0.1', 27017)
        self.remote_db = self.client.remote_jobs.software_dev
        self.tech_db = self.client.tech_job.dice
    
    def find_one_by_id(self, job_id, db):
        job = db.find_one({'job_id': job_id})
        return job
    

def get_entities(doc):
    ent_map = {}
    for ent in doc.ents:
        label = category_map.get(ent.label_)
        if not label:     
            label = "'" + ent.label_ + "'" 
        index = '(' + str(ent.start_char) + ', ' + str(ent.end_char) + ', ' + label + ')' + ', '
        ent_map[index] = ent
    return ent_map

# %%
nlp = en_core_web_lg.load()

# %%
job_nlp = spacy.load(job_model_path)

# %%
job = MongoManager().find_one_by_id("f31096e3a08b479d8e10e5f1e1161a4af18b5d626cbe51a12d80cd5295a42038", MongoManager().tech_db)
desc = job['job_desc']

# %%
doc2 = job_nlp(desc)
ent_map = get_entities(doc2)
# for key, value in ent_map.items():
#     print(value, key)
end_index_map = {}
for key in ent_map.keys():
    print(key)
    tag = key.split()[2] 
    if "'" in tag:
        val = tag[1:-3]
    else:
        val = tag[:-2]
    end_index_map[key.split()[1][:-1]] = val
# Out:
# (25, 29, pl),
# (30, 39, ps),
# (61, 74, 'GPE'),
# (76, 78, 'GPE'),
# (160, 164, pl),
# (165, 183, ps),
# (195, 208, 'GPE'),
# (210, 212, 'GPE'),
# (223, 225, 'CARDINAL'),
# (305, 311, dv),
# (319, 331, ql),
# (442, 447, ap),
# (518, 523, ap),
# (1055, 1067, at),
# (1224, 1229, ap),
# (1256, 1268, at),
# (1314, 1330, cs),
# (1407, 1411, pl),
# (1464, 1468, pl),
# (1505, 1509, pl),
# (1533, 1541, pl),
# (1543, 1546, pl),
# (1548, 1552, pl),
# (1564, 1581, pf),
# (1602, 1605, ol),
# (1607, 1610, ap),
# (1616, 1619, 'ORG'),
# (1627, 1649, ap),
# (1686, 1692, dv),
# (1714, 1719, ds),
# (1732, 1737, ds),
# (1780, 1802, ap),
# (1810, 1817, tl),
# (1835, 1845, we),
# (1851, 1861, pl),
# (1862, 1865, pl),
# (1873, 1878, lb),
# (1881, 1886, lb),
# (1921, 1927, dv),
# (1944, 1954, we),
# (1968, 1978, we),
# (2022, 2027, pf),
# (2029, 2034, pf),
# (2039, 2052, pf),
# (2108, 2131, ap),
# (2136, 2163, ap),
# (2167, 2171, 'ORG'),
# (2233, 2244, at),
# (2249, 2267, ql),
# (2279, 2289, we),
# (2293, 2303, se),
# (2427, 2437, we),
# (2443, 2448, ap),
# (2490, 2510, sf),
# (2521, 2525, pl),
# (2527, 2531, pf),
# (2533, 2538, ds),
# (2540, 2545, lb),
# (2550, 2555, lb),
# (2557, 2562, pf),
# (2575, 2578, ol),
# (2580, 2583, pt),
# (2585, 2588, ol),
# (2590, 2595, ap),
# (2605, 2613, fw),

# %%
displacy.render(doc2, style="ent")
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Hi We are looking for Sr
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Java
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROGRAMMING_LANGUAGE</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Developer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
#  for Direct client in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     San Francisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  . Please send me updated resume with contact details to discuss this further. Sr
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Java
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROGRAMMING_LANGUAGE</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Back End Developer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
#  Location :
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     San Francisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Duration :
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# + Months Participate in requirement gathering and technical design discussions.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Design
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DIVISION</span>
# </mark>
#  highly
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     scalable and
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUALITY</span>
# </mark>
#  high performing technology solutions. Provide technical knowledge and guidance to the team. Participate in an
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Agile
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">APPROACH</span>
# </mark>
#  work environment, to produce and deliver code and/or test cases using
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Agile
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">APPROACH</span>
# </mark>
#  practices. Work closely with production support team and assist in resolving critical production issues. Work closely with the business and functional professionals and help simplify and improve the processes through the latest in technology and automation. Be updated on the latest offerings in technology and methodology in the market and perform proof of concepts to better understand how they fit into the Client landscape and their usefulness and effectiveness to the organization if adopted. Be responsible for technical and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     architecture
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ARCHITECT</span>
# </mark>
#  implementation against the agreed scope and quality of the end product delivered. Works closely with Technical Lead, Technical Manager, Product manager and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Scrum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">APPROACH</span>
# </mark>
#  Master to balance product
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     architecture
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ARCHITECT</span>
# </mark>
#  and delivery timeline. Requirements: • BS in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     computer science
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COMPUTER_SCIENCE</span>
# </mark>
#  or equivalent. • Software engineering development experience which includes
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Java
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROGRAMMING_LANGUAGE</span>
# </mark>
# /J2ee specific experience. • Robust understanding of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Java
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROGRAMMING_LANGUAGE</span>
# </mark>
# , an in depth understanding of other
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Java
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transfo

# %%
doc = nlp(desc)
ent_map = get_entities(doc)
for key, value in ent_map.items():
    tag = key.split()[2] 
    if "'" in tag:
        val = tag[1:-3]
    else:
        val = tag[:-2]
    if key.split()[1][:-1] not in end_index_map.keys() or end_index_map[key.split()[1][:-1]] != val:
        print(value, key)
# Out:
# Direct (44, 50, 'ORG'),
# Java Back End Developer Location (160, 192, 'PRODUCT'),
# 12+ Months (223, 233, 'DATE'),
# • Software (1346, 1356, 'ORG'),
# Java/J2ee (1407, 1416, 'ORG'),
# Java (1464, 1468, 'ORG'),
# Java (1505, 1509, 'ORG'),
# Servlets (1533, 1541, 'PRODUCT'),
# JSP (1543, 1546, 'ORG'),
# JDBC (1548, 1552, 'ORG'),
# J2EE (1564, 1568, 'PRODUCT'),
# XML (1602, 1605, 'ORG'),
# XSD (1607, 1610, 'ORG'),
# Mongo (1732, 1737, 'PERSON'),
# Jenkins (1810, 1817, 'PERSON'),
# React & Redux (1873, 1886, 'ORG'),
# Azure and Pivotal Cloud Foundry (2029, 2060, 'WORK_OF_ART'),
# Test Driven Development and Business Driven Development (2108, 2163, 'ORG'),
# SOA (2316, 2319, 'ORG'),
# SOA (2370, 2373, 'ORG'),
# Java (2521, 2525, 'ORG'),
# J2EE (2527, 2531, 'PRODUCT'),
# NOSQL (2533, 2538, 'ORG'),
# SOA (2571, 2574, 'ORG'),
# XSD (2580, 2583, 'ORG'),
# XSL (2585, 2588, 'ORG'),
# Agile Regards (2590, 2603, 'ORG'),
# Vaishali Wagh Resource (2605, 2627, 'ORG'),
# | MatchPoint Solutions | Office (2636, 2667, 'ORG'),
# 9 25-304-1846 (2668, 2681, 'DATE'),
# 925-818-4052 | Email (2689, 2709, 'PRODUCT'),

# %%
displacy.render(doc, style="ent")
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Hi We are looking for Sr Java Developer for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Direct
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  client in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     San Francisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , CA . Please send me updated resume with contact details to discuss this further. Sr
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Java Back End Developer Location
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  :
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     San Francisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , CA Duration :
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12+ Months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Participate in requirement gathering and technical design discussions. Design highly scalable and high performing technology solutions. Provide technical knowledge and guidance to the team. Participate in an Agile work environment, to produce and deliver code and/or test cases using Agile practices. Work closely with production support team and assist in resolving critical production issues. Work closely with the business and functional professionals and help simplify and improve the processes through the latest in technology and automation. Be updated on the latest offerings in technology and methodology in the market and perform proof of concepts to better understand how they fit into the Client landscape and their usefulness and effectiveness to the organization if adopted. Be responsible for technical and architecture implementation against the agreed scope and quality of the end product delivered. Works closely with Technical Lead, Technical Manager, Product manager and Scrum Master to balance product architecture and delivery timeline. Requirements: • BS in computer science or equivalent.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     • Software
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  engineering development experience which includes
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Java/J2ee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  specific experience. • Robust understanding of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Java
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , an in depth understanding of other
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Java
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  technologies including
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Servlets
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JSP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JDBC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and other
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     J2EE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  technologies; • familiarity with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     XML
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     XSD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     XSL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Other object-oriented design experience, and experience applying design patterns. • Hands-on NoSQL experience,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mongo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  strongly preferred. • Experience in using Continuous Integration tools,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jenkins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is a big plus. • Experience with JavaScript/ES6 and/or
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     React &amp; Redux
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppe

# %%
desc[784:]
# Out:
# ' updated on the latest offerings in technology and methodology in the market and perform proof of concepts to better understand how they fit into the Client landscape and their usefulness and effectiveness to the organization if adopted. Be responsible for technical and architecture implementation against the agreed scope and quality of the end product delivered. Works closely with Technical Lead, Technical Manager, Product manager and Scrum Master to balance product architecture and delivery timeline. Requirements: • BS in computer science or equivalent. • Software engineering development experience which includes Java/J2ee specific experience. • Robust understanding of Java, an in depth understanding of other Java technologies including Servlets, JSP, JDBC, and other J2EE technologies; • familiarity with XML, XSD, and XSL. Other object-oriented design experience, and experience applying design patterns. • Hands-on NoSQL experience, Mongo strongly preferred. • Experience in using Continuous Integration tools, Jenkins is a big plus. • Experience with JavaScript/ES6 and/or React & Redux is a plus • Should understand the DevOps model, Hands-on experience is a plus. • Experience in using containerization technologies and cloud, Azure and Pivotal Cloud Foundry preferred. • Should understand the concepts of Test Driven Development and Business Driven Development. • Full lifecycle development experience on large projects, creating distributed and scalable eCommerce systems. • Experience in developing and driving SOA strategies within large enterprises and deploying SOA implementations to production a big plus. • Hands on experience with Agile methodologies highly desirable. • Strong communication skills. Skills : Java, J2EE, NOSQL, React and Redux, Cloud, Azure, SOA XML, XSD, XSL, Agile Regards, Vaishali Wagh Resource Manager | MatchPoint Solutions | Office 9 25-304-1846 | Cell 925-818-4052 | Email'

# %%
test = """The two stocks that contributed the most to 2019’s total stock-market returns also hold that position for the entire decade.

While it’s fun to look at how the overall composition of the top 10 contributors has changed — with a noticeable shift from the energy sector to finance, for example — it’s perhaps more interesting to note the enduring heft of Apple Inc. AAPL, +0.73% and Microsoft Corp. MSFT, +0.07%  for investors, as the chart shows.

The two companies didn’t just dominate. They actually intensified their hold over the past decade, moving from a share of 8.45% of the total S&P 500 SPX, +0.29% return over the decade to 14.8% over the last 12 months through Dec. 27, according to data compiled by Howard Silverblatt, senior index analyst at S&P Dow Jones Indices.

As Barron’s noted, the two tech giants are the only companies with valuations of more than $1 trillion.

See: ‘Apple a value stock?’ The Great Rotation takes a strange spin

Rounding out the top 10 contributors to returns since 2009: Home Depot Inc. HD, +0.49%, Pfizer Inc. PFE, +0.69%, JPMorgan Chase & Co. JPM, +0.56%, Chevron Corp. CVX, +0.55%, and Berkshire Hathaway Class B. BRK.B, +0.33% For the past year, that includes Mastercard Inc. MA, +0.29%, Visa Inc. V, +0.04%, Bank of America Corp. BAC, +0.20%, AT&T T, +0.10%, and Alphabet Inc. Class C GOOG, +0.07%.

And Apple and Microsoft weren’t the only stocks intensifying their hold over the market. The top 10 contributors made up about 19.6% of the total stock market return over the decade, but 29.5% over the past year."""

# %%
end_index_map
# Out:
# {'29': 'pl',
#  '39': 'ps',
#  '74': 'GPE',
#  '78': 'GPE',
#  '164': 'pl',
#  '183': 'ps',
#  '208': 'GPE',
#  '212': 'GPE',
#  '225': 'CARDINAL',
#  '311': 'dv',
#  '331': 'ql',
#  '447': 'ap',
#  '523': 'ap',
#  '1067': 'at',
#  '1229': 'ap',
#  '1268': 'at',
#  '1330': 'cs',
#  '1411': 'pl',
#  '1468': 'pl',
#  '1509': 'pl',
#  '1541': 'pl',
#  '1546': 'pl',
#  '1552': 'pl',
#  '1581': 'pf',
#  '1605': 'ol',
#  '1610': 'ap',
#  '1619': 'ORG',
#  '1649': 'ap',
#  '1692': 'dv',
#  '1719': 'ds',
#  '1737': 'ds',
#  '1802': 'ap',
#  '1817': 'tl',
#  '1845': 'we',
#  '1861': 'pl',
#  '1865': 'pl',
#  '1878': 'lb',
#  '1886': 'lb',
#  '1927': 'dv',
#  '1954': 'we',
#  '1978': 'we',
#  '2027': 'pf',
#  '2034': 'pf',
#  '2052': 'pf',
#  '2131': 'ap',
#  '2163': 'ap',
#  '2171': 'ORG',
#  '2244': 'at',
#  '2267': 'ql',
#  '2289': 'we',
#  '2303': 'se',
#  '2437': 'we',
#  '2448': 'ap',
#  '2510': 'sf',
#  '2525': 'pl',
#  '2531': 'pf',
#  '2538': 'ds',
#  '2545': 'lb',
#  '2555': 'lb',
#  '2562': 'pf',
#  '2578': 'ol',
#  '2583': 'pt',
#  '2588': 'ol',
#  '2595': 'ap',
#  '2613': 'fw'}
