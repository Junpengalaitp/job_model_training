# %%
import os

import pandas as pd
import spacy
import en_core_web_lg
from spacy import displacy

from constants.category import category_map
from database.sqlalchemy_manager import conn

# %%
BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath('__file__')))
job_model_path = os.path.join(BASE_DIR, "job_model_sm")

# %%
nlp = en_core_web_lg.load()

# %%
job_nlp = spacy.load(job_model_path)

# %%
job_id = "e96b79feedfda5ca4075fdf661abb8e1a2f3e798e8ef8ffaede2a55a50b75eb7"
query = f"""SELECT * FROM dice_job WHERE job_id = '{job_id}'"""
job = pd.read_sql_query(query, conn)

# %%
desc = job['job_desc'][0]
desc
# Out:
# "The Team: Our Cloud Engineering team focuses on enabling our client's end to end journey from On-Premise to Cloud, with opportunities in the areas of: Cloud Strategy, Op Model Transformation, Cloud Development, Cloud Integration & APIs, Cloud migration, Cloud Infrastructure & Engineering, and Cloud Managed Services. We help our clients see the transformational capabilities of Cloud as an opportunity for business enablement and competitive advantage. Cloud Engineering supports our clients as they improve agility and resilience, and identifies opportunities to reduce IT operations spend through automation by enabling Cloud. We accelerate our clients towards a technology-driven future, leveraging vendor solutions and Deloitte-developed software products, tools, and accelerators. Work you'll do: In partnership with other leaders in the firm, you will focus on selling and delivering cloud solutions using Azure and as a key member of Architecture group, ensure success in building and migr
# ...

# %%
# get entity annotation from job model
job_doc = job_nlp(desc)
ent_map = get_entities(job_doc)
end_index_map = {}
for key in ent_map.keys():
    print(key)
    tag = key.split()[2] 
    if "'" in tag:
        val = tag[1:-3]
    else:
        val = tag[:-2]
    end_index_map[key.split()[1][:-1]] = val
# Out:
# (14, 19, pf),
# (108, 113, pf),
# (151, 156, pf),
# (192, 197, pf),
# (198, 209, se),
# (211, 216, pf),
# (217, 228, se),
# (231, 235, pt),
# (237, 242, pf),
# (254, 259, pf),
# (294, 299, pf),
# (379, 384, pf),
# (431, 452, of),
# (454, 459, pf),
# (623, 628, pf),
# (891, 896, pf),
# (913, 918, pf),
# (942, 954, at),
# (1049, 1054, pf),
# (1071, 1076, pf),
# (1199, 1204, pf),
# (1321, 1326, pf),
# (1388, 1393, pf),
# (1404, 1413, ps),
# (1465, 1470, pf),
# (1617, 1622, pf),
# (1776, 1786, we),
# (1823, 1828, pf),
# (1843, 1847, pf),
# (1849, 1853, fw),
# (1859, 1864, pf),
# (2011, 2016, pf),
# (2033, 2039, pf),
# (2041, 2047, pf),
# (2052, 2061, 'ORG'),
# (2063, 2073, we),
# (2082, 2099, tm),
# (2100, 2105, se),
# (2110, 2116, se),
# (2161, 2166, pf),
# (2167, 2177, we),
# (2183, 2205, ap),
# (2208, 2229, ap),
# (2402, 2415, 'PERCENT'),
# (2427, 2436, 'DATE'),
# (2448, 2458, we),
# (2484, 2491, 'DATE'),
# (2507, 2516, dv),
# (2526, 2538, at),
# (2562, 2582, se),
# ...

# %%
displacy.render(job_doc, style="ent")
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">The Team: Our
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cloud
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PLATFORM</span>
# </mark>
#  Engineering team focuses on enabling our client's end to end journey from On-Premise to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cloud
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PLATFORM</span>
# </mark>
# , with opportunities in the areas of:
# ...

# %%
# get entity annotations from en_core_web_lg that are not in job model
doc = nlp(desc)
ent_map = get_entities(doc)
for key, value in ent_map.items():
    tag = key.split()[2] 
    if "'" in tag:
        val = tag[1:-3]
    else:
        val = tag[:-2]
    if key.split()[1][:-1] not in end_index_map.keys() or end_index_map[key.split()[1][:-1]] != val:
        print(value, key)
# Out:
# Cloud Engineering (14, 31, 'ORG'),
# Cloud Strategy (151, 165, 'WORK_OF_ART'),
# Op Model Transformation (167, 190, 'ORG'),
# Cloud Development (192, 209, 'ORG'),
# Cloud Integration & APIs (211, 235, 'ORG'),
# Cloud Infrastructure & Engineering (254, 288, 'ORG'),
# Cloud Managed Services (294, 316, 'ORG'),
# Cloud (379, 384, 'ORG'),
# Cloud Engineering (454, 471, 'ORG'),
# Cloud (623, 628, 'ORG'),
# Deloitte (724, 732, 'ORG'),
# Azure (913, 918, 'PRODUCT'),
# Architecture (942, 954, 'ORG'),
# Capture (1327, 1334, 'PRODUCT'),
# Azure (1823, 1828, 'PRODUCT'),
# J2EE (1843, 1847, 'PRODUCT'),
# Direct (1940, 1946, 'ORG'),
# Amazon (2033, 2039, 'ORG'),
# Google (2041, 2047, 'ORG'),
# Java / J2EE (2631, 2642, 'ORG'),
# Architecting (2660, 2672, 'PRODUCT'),
# GCP (2781, 2784, 'ORG'),
# AWS (2795, 2798, 'ORG'),
# Azure (2861, 2866, 'PRODUCT'),
# Amazon Web Services (2870, 2889, 'ORG'),
# Electrical Engineering (2959, 2981, 'ORG'),
# Azure Certified Professional (3028, 3056, 'WORK_OF_ART'),
# ...

# %%
displacy.render(doc, style="ent")
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">The Team: Our
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cloud Engineering
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  team focuses on enabling our client's end to end journey from On-Premise to Cloud, with opportunities in the areas of:
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cloud Strategy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# ,
# ...
