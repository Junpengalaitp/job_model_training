# %%
import os

from pymongo import MongoClient
import spacy
import en_core_web_lg
from spacy import displacy

from constants.category import category_map

# %%
BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath('__file__')))
job_model_path = os.path.join(BASE_DIR, "job_model")

# %%
class MongoManager:
    def __init__(self):
#         user = 'root'
#         password = 'root'
#         self.client = MongoClient(f'mongodb://{user}:{password}@192.168.1.39', 27018)
        self.client = MongoClient(f'mongodb://127.0.0.1', 27017)
        self.remote_db = self.client.remote_jobs.software_dev
        self.tech_db = self.client.tech_job.dice
    
    def find_one_by_id(self, job_id, db):
        job = db.find_one({'job_id': job_id})
        return job

# %%
nlp = en_core_web_lg.load()

# %%
job_nlp = spacy.load(job_model_path)

# %%
job = MongoManager().find_one_by_id("8387c0335bde4a263f0939c6331fba2fe4a68e48aee796efc6d8a4ab910c532d", MongoManager().tech_db)
desc = job['job_desc']

# %%
desc
# Out:
# 'Minimum Required Skills: Android, Algorithm, Algorithmic, IOS, SWIFT, Objective C, AI, AWS, Healthkit API, Google Fit API If you are a Mobile Developer with experience, please read on! Based in Irvine, CA, we are an exciting, well-funded startup that is revolutionizing digital health management and saving the lives of the patients that use our application. We use artificial intelligence to assess their behavior and give them customized suggestions on healthy choices according to ADA guidelines. What You Will Be Doing - Helping the development team build a digital health solution for diabetes management in collaboration with leading experts in endocrinology and artificial intelligence. - Working in an Agile Environment What You Need for this Position " Bachelors degree in computer science, computer engineering or related fields " Minimum 2-5 years of development experience focusing on mobile applications development in iOS or Android environment " Must understand fundamental AI and machine learning concepts " Must have tracking record of product development experience, preferably in highly regulated industry, and in high volume consumer market " Experience with integrated front-end, back-end applications or data service, and familiar with full stack development environment Nice to Have Skills Include: " Data science, AI, or machine learning knowledge " iOS, Android, and AWS SDK " Client/Server architecture and implementation " HealthKit API " Google Fit API " ML framework experience with Node.js, SQL/NoSQL and AWS cloud environments " Actively tracker integration (Fitbit, Apple Watch, etc) " Familiarity with HIPAA regulations and cyber security What\'s In It for You - Competitive Base Salary DOE - Medical - DentalSo, if you are a Mobile Developer with experience, please apply today! Applicants must be authorized to work in the U.S. Security Clearance will be needed - therefore, Those authorized to work in the United States without sponsorship are encouraged to apply.s can be considered.Please apply directly to by clicking \'Click Here to Apply\' with your Word resume! Looking forward to receiving your resume and going over the position in more detail with you. - Not a fit for this position? Click the link at the bottom of this email to search all of our open positions. Looking forward to receiving your resume! CyberCoders CyberCoders, Inc is proud to be an Equal Opportunity Employer All qualified applicants will receive consideration for employment without regard to race, color, religion, sex, national origin, disability, protected veteran status, or any other characteristic protected by law. Your Right to Work - In compliance with federal law, all persons hired will be required to verify identity and eligibility to work in the United States and to complete the required employment eligibility verification document form upon hire. Copyright 1999 - 2020 . CyberCoders, Inc. All rights reserved.'

# %%
doc = nlp(desc)
ent_map = get_entities(doc)
for key, value in ent_map.items():
    print(value, key)
# Out:
# Algorithm (34, 43, 'ORG'),
# Algorithmic (45, 56, 'ORG'),
# IOS (58, 61, 'ORG'),
# SWIFT (63, 68, 'ORG'),
# Objective C (70, 81, 'ORG'),
# AI (83, 85, 'ORG'),
# AWS (87, 90, 'ORG'),
# Google (107, 113, 'ORG'),
# API (118, 121, 'ORG'),
# Mobile (135, 141, 'GPE'),
# Irvine (194, 200, 'GPE'),
# ADA (484, 487, 'ORG'),
# iOS (932, 935, 'ORG'),
# Android (939, 946, 'ORG'),
# AI (989, 991, 'ORG'),
# iOS (1374, 1377, 'ORG'),
# Android (1379, 1386, 'ORG'),
# Node.js (1512, 1519, 'ORG'),
# SQL/NoSQL (1521, 1530, 'ORG'),
# AWS (1535, 1538, 'ORG'),
# Fitbit (1590, 1596, 'ORG'),
# Apple Watch (1598, 1609, 'ORG'),
# Familiarity with HIPAA regulations and cyber security (1618, 1671, 'WORK_OF_ART'),
# 's In It for You - Competitive Base Salary (1676, 1718, 'WORK_OF_ART'),
# Mobile Developer (1758, 1774, 'GPE'),
# today (1805, 1810, 'DATE'),
# the U.S. Security Clearance (1853, 1880, 'ORG'),
# the United States (1937, 1954, 'GPE'),
# Inc (2373, 2376, 'GPE'),
# the United States (2770, 2787, 'GPE'),
# 1999 - 2020 (2888, 2899, 'DATE'),
# CyberCoders (2902, 2913, 'ORG'),

# %%
displacy.render(doc, style="ent")
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Minimum Required Skills: Android,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Algorithm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Algorithmic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SWIFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Objective C
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AWS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Healthkit API,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Fit
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     API
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  If you are a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mobile
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Developer with experience, please read on! Based in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Irvine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , CA, we are an exciting, well-funded startup that is revolutionizing digital health management and saving the lives of the patients that use our application. We use artificial intelligence to assess their behavior and give them customized suggestions on healthy choices according to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ADA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  guidelines. What You Will Be Doing - Helping the development team build a digital health solution for diabetes management in collaboration with leading experts in endocrinology and artificial intelligence. - Working in an Agile Environment What You Need for this Position &quot; Bachelors degree in computer science, computer engineering or related fields &quot; Minimum 2-5 years of development experience focusing on mobile applications development in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  or
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Android
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  environment &quot; Must understand fundamental
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and machine learning concepts &quot; Must have tracking record of product development experience, preferably in highly regulated industry, and in high volume consumer market &quot; Experience with integrated front-end, back-end applications or data service, and familiar with full stack development environment Nice to Have Skills Include: &quot; Data science, AI, or machine learning knowledge &quot;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Android
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and AWS SDK &quot; Client/Server architecture and implementation &quot; HealthKit API &quot; Google Fit API &quot; ML framework experience with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Node.js
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SQL/NoSQL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AWS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform:

# %%
doc2 = job_nlp(desc)
ent_map = get_entities(doc2)
# for key, value in ent_map.items():
#     print(value, key)
for key in ent_map.keys():
    print(key)
# Out:
# (25, 32, os),
# (34, 43, lb),
# (45, 56, tl),
# (58, 61, os),
# (63, 68, tl),
# (70, 81, pl),
# (87, 90, pf),
# (92, 101, tl),
# (102, 105, pt),
# (107, 121, pf),
# (135, 151, ps),
# (194, 200, 'GPE'),
# (238, 245, cp),
# (366, 389, ai),
# (484, 487, 'ORG'),
# (669, 692, ai),
# (710, 715, ap),
# (782, 798, cs),
# (800, 820, ap),
# (849, 858, 'DATE'),
# (862, 884, we),
# (897, 916, pd),
# (932, 935, os),
# (939, 946, os),
# (989, 991, sv),
# (996, 1012, ai),
# (1190, 1199, pd),
# (1201, 1209, dv),
# (1345, 1361, ai),
# (1374, 1377, os),
# (1379, 1386, os),
# (1392, 1395, pf),
# (1460, 1463, pt),
# (1466, 1480, pf),
# (1512, 1519, sv),
# (1521, 1524, ol),
# (1525, 1530, ds),
# (1535, 1538, pf),
# (1569, 1576, pf),
# (1577, 1588, se),
# (1590, 1596, tl),
# (1598, 1609, 'ORG'),
# (1635, 1640, pt),
# (1657, 1671, ap),
# (1758, 1774, ps),
# (1805, 1810, 'DATE'),
# (1857, 1861, 'GPE'),
# (1993, 2000, 'ORG'),
# (2395, 2412, of),
# (2888, 2899, of),

# %%
displacy.render(doc2, style="ent")
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Minimum Required Skills:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Android
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OS</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Algorithm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LIBRARY</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Algorithmic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TOOL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">OS</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SWIFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TOOL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Objective C
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROGRAMMING_LANGUAGE</span>
# </mark>
# , AI,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AWS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PLATFORM</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Healthkit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TOOL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     API
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROTOCOL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google Fit API
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PLATFORM</span>
# </mark>
#  If you are a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mobile Developer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
#  with experience, please read on! Based in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Irvine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , CA, we are an exciting, well-funded
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     startup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  that is revolutionizing digital health management and saving the lives of the patients that use our application. We use
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artificial intelligence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">AI</span>
# </mark>
#  to assess their behavior and give them customized suggestions on healthy choices according to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ADA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  guidelines. What You Will Be Doing - Helping the development team build a digital health solution for diabetes management in collaboration with leading experts in endocrinology and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artificial intelligence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">AI</span>
# </mark>
# . - Working in an
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Agile
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">APPROACH</span>
# </mark>
#  Environment What You Need for this Position &quot; Bachelors degree in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     computer science
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COMPUTER_SCIENCE</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     computer engineering
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">APPROACH</span>
# </mark>
#  or related fields &quot; Minimum
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2-5 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     development experience
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_EXPERIENCE</span>
# </mark>
#  focusing on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mobile applications
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: u

# %%
def get_entities(doc):
    ent_map = {}
    for ent in doc.ents:
        label = category_map.get(ent.label_)
        if not label:     
            label = "'" + ent.label_ + "'" 
        index = '(' + str(ent.start_char) + ', ' + str(ent.end_char) + ', ' + label + ')' + ', '
        ent_map[index] = ent
    return ent_map

# %%
desc[3006:]
# Out:
# ''

# %%
test = """The two stocks that contributed the most to 2019’s total stock-market returns also hold that position for the entire decade.

While it’s fun to look at how the overall composition of the top 10 contributors has changed — with a noticeable shift from the energy sector to finance, for example — it’s perhaps more interesting to note the enduring heft of Apple Inc. AAPL, +0.73% and Microsoft Corp. MSFT, +0.07%  for investors, as the chart shows.

The two companies didn’t just dominate. They actually intensified their hold over the past decade, moving from a share of 8.45% of the total S&P 500 SPX, +0.29% return over the decade to 14.8% over the last 12 months through Dec. 27, according to data compiled by Howard Silverblatt, senior index analyst at S&P Dow Jones Indices.

As Barron’s noted, the two tech giants are the only companies with valuations of more than $1 trillion.

See: ‘Apple a value stock?’ The Great Rotation takes a strange spin

Rounding out the top 10 contributors to returns since 2009: Home Depot Inc. HD, +0.49%, Pfizer Inc. PFE, +0.69%, JPMorgan Chase & Co. JPM, +0.56%, Chevron Corp. CVX, +0.55%, and Berkshire Hathaway Class B. BRK.B, +0.33% For the past year, that includes Mastercard Inc. MA, +0.29%, Visa Inc. V, +0.04%, Bank of America Corp. BAC, +0.20%, AT&T T, +0.10%, and Alphabet Inc. Class C GOOG, +0.07%.

And Apple and Microsoft weren’t the only stocks intensifying their hold over the market. The top 10 contributors made up about 19.6% of the total stock market return over the decade, but 29.5% over the past year."""
